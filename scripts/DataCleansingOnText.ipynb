# %% [markdown]
# #### Text Sources:
# * https://zh.wikipedia.org/zh-tw/Wikipedia:%E6%95%B0%E6%8D%AE%E5%BA%93%E4%B8%8B%E8%BD%BD
# * https://dumps.wikimedia.org/zhwiki/20210401/
# * https://dumps.wikimedia.org/

# %%
text = '数学https://stackoverflow.com/questions/11331982/how-to-remove-any-url-within-a-string-in-pythonDECS'
"&lt" in text
# Out:
# True
