# %% [markdown]
# # Monpa Tryout
# * GitHub Documentation: https://github.com/monpa-team/monpa

# %%
# import packages
from monpa import utils
from tqdm import tqdm
import codecs
import monpa
import numpy as np
import os
import pandas as pd
# Out:
# +---------------------------------------------------------------------+
#   Welcome to MONPA: Multi-Objective NER POS Annotator for Chinese
# +---------------------------------------------------------------------+
# 已找到 model檔。Found model file.

# %%
os.getcwd()
# Out:
# 'D:\\Windows_Storage\\Storage\\Github\\KnowledgeGraph\\scripts\\tokenizations'

# %% [markdown]
# # Import Data

# %%
textElement = ""

file = codecs.open("../../data/矽晶圓製造業資源化應用技術手冊.txt", 'r', encoding='utf8', errors='ignore')

for textIndex, textLines in enumerate(file):
    textElement += textLines
    
print(textElement[:500])
# Out:
#
#
#
# 矽晶圓製造業資源化應用技術手冊
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 經  濟  部  工  業  局
#
# 財團
# 法人台灣綠色生產力基金會
#
#
#
# 出版機關：    經濟部工業局
#
# 出版日期：中華民國 96 年 8 月
#
#
#
# 編著
#
#
# 序
#
# 半 導 體 製 造 流 程 係 包 括 IC 設 計、IC 晶 圓 製 造、IC 封 裝、IC 測 試
# 等 階 段 ， 依 上 、 中 、 下 游 來 劃 分 半 導 體 產 業 整 體 結 構 ， IC 設 計 應 屬 半
# 導 體 上 游 產 業 、 IC 晶 圓 製 造 則 屬 中 游 產 業 ； IC 封 裝 、 IC 測 試 則 屬 下
# 游 產 業 。 矽 晶 圓 製 造 業 於 整 個 半 導 體 產 業 架 構 中 係 擔 任 晶 圓 材 料 供 應
# 者 角 色 。 隨 著 半 導 體 產 業 與 太 陽 能 電 池 產 業 的 蓬 勃 發 展 ， 對 矽 晶 圓 材
# 料 的 需 求 急 速 增 加 ， 矽 晶 圓 製 造 業 的 產 能 不 斷 增 加 ， 衍 生 的 是 如

# %% [markdown]
# # Further Train Data

# %%
monpa.load_userdict("../dicts/monpa_userDefinedDict.txt")

# %% [markdown]
# # Shorten Sentence to Fit Monpa Cut/Pseg Function

# %%
textList = utils.short_sentence(textElement)
# for item in textList:
#     print(item)

# %% [markdown]
# # Cut Function

# %%
# cutResultList = []

# for textIndex, textElement in enumerate(textList):
#     cutResult = monpa.cut(textElement)
#     cutResultList.append(cutResult)

# print(cutResultList)
# Out:
# [['矽晶圓', '製造業', '資源', '化', '應用', '技術', '手冊', '                                      ', '經  濟  部  工  業  局   財團 法人', '台灣綠色生產力基金會', '      ', '出版', '機關', '：', '    ', '經濟部工業局', '   ', '出版', '日期', '：', '中華民國 ', '96 年', ' ', '8 月', '      編著    序   半 ', '導 ', '體 ', '製', ' 造', ' 流 程 係 包 括 ', 'IC', ' ', '設', ' 計', '、', 'IC', ' ', '晶 ', '圓 ', '製', ' 造', '、', 'IC', ' 封', ' 裝', '、', 'IC', ' ', '測'], ['試', ' 等', ' 階', ' 段', ' ', '，', ' 依', ' 上', ' ', '、', ' 中 ', '、', ' 下', ' 游', ' 來', ' ', '劃', ' 分', ' ', '半 ', '導', ' 體', ' 產', ' 業', ' ', '整', ' 體', ' 結', ' 構', ' ', '，', ' ', 'IC', ' ', '設', ' 計', ' ', '應 ', '屬', ' ', '半 ', '
na'), ('體 ', 'Na'), ('製', 'VC'), (' 造', 'Na'), (' 流 程 係 包 括 ', 'PER'), ('IC', 'FW'), (' ', 'Na'), ('設', 'VC'), (' 計', 'Na'), ('、', 'PAUSECATEGORY'), ('IC', 'FW'), (' ', 'Na'), ('晶 ', 'Na'), ('圓 ', 'Na'), ('製', 'VC'), (' 造', 'Na'), ('、', 'PAUSECATEGORY'), ('IC', 'FW'), (' 封', 'Na'), (' 裝', 'Na'), ('、', 'PAUSECATEGORY'), ('IC', 'FW'), (' ', 'FW'), ('測', 'VC')], [('試', 'VC'), (' 等', 'Na'), (' 階', 'Na'), (' 段', 'Na'), (' ', 'Na'), ('，', 'COMMACATEGORY'), (' 依', 'Nb'), (' 上', 'Na'), (' ', 'Na'), ('、', 'PAUSECATEGORY'), (' 中 ', 'Nb'), ('、', 'PAUSECATEGORY'), (' 下', 'Na'), (' 游', 'Na'), (' 來', 'Na'), (' ', 'Na'), ('劃', 'VC'), (' 分', 'Na'), (' ', 'Na'), ('半 ', 'Na'), ('導', 'VC'), (' 體', 'Na'), (' 產', 'Na'), (' 業', 'Na'), (' ', 'FW'), ('整', 'VC'), (' 體', 'Na'), (' 結', 'Na'), (' 構', 'Na'), (' ', 'Na'), ('，', 'COMMACATEGORY'), (' ', 'FW'), ('IC', 'FW'), (' ', 'FW'), ('設', 'VC'), (' 計', 'Na'), (' ', 'FW'), ('應 ', 'Na'), ('屬', 'VG'), (' ', 'FW'), ('半 ', 'Na'), ('導', 'VC'), (' 體', 'Na'), (' ', 'FW'), ('上', 'Ng'), (' 游', 'Na'), (' 產', 'Na'), (' 業', 'Na'), (' ', 'Na'), ('、', 'PAUSECATEGORY'), (' ', 'Na'), ('IC', 'FW'), (' 晶', 'Na'), (' 圓', 'Na'), (' ', 'Na'), ('製', 'VC'), (' 造', 'Na'), (' ', 'FW'), ('則', 'D'), (' 屬', 'Na'), (' ', 'FW'), ('中 ', 'Na'), ('游', 'Na'), (' 產', 'Na'), (' 業', 'Na'), (' ', 'Na'), ('；', 'PERIODCATEGORY'), (' ', 'FW'), ('IC', 'FW'), (' 封', 'Na'), (' ', 'Na'), ('裝 ', 'Na'), ('、', 'PAUSECATEGORY'), (' ', 'Na'), ('IC', 'FW'), (' ', 'Na'), ('測 ', 'Na'), ('試', 'VC'), (' 則', 'Na'), (' 屬', 'Na'), (' 下', 'Na'), (' 游', 'Na'), (' 產', 'Na'), (' 業', 'Na'), (' ', 'Na'), ('。', 'PERIODCATEGORY'), (' ', 'Na'), ('矽', 'Na'), (' 晶', 'Na'), (' 圓', 'Na'), (' ', 'Na'), ('製', 'VC'), (' 造', 'Na'), (' 業', 'Na'), (' ', 'Na'), ('於', 'P'), (' ', 'FW'), ('整', 'Neqa'), (' ', 'FW'), ('個', 'Nf'), (' 半', 'Na'), (' 導', 'Na'), (' 體', 'Na'), (' 產', 'Na'), (' 業', 'Na'), (' 架', 'Na'), (' 構', 'Na'), (' 中', 'Na'), (' 係', 'Na'), (' 擔', 'Na'), (' 任', 'Na'), (' 晶', 'Na'), (' 圓', 'Na'), (' 材', 'Na'), (' 料', 'Na'), (' 供', 'Na'), (' 應', 'Na'), (' 者', 'Na'), (' 角', 'Na'), (' 色', 'Na'), (' ', 'Na'), ('。', 'PERIODCATEGORY')], [('隨', 'P'), (' ', 'Na'), ('著', 'Di'), (' 半', 'Na'), (' ', 'Na'), ('導', 'VC'), (' 體', 'Na'), (' ', 'FW'), ('產 ', 'Na'), ('業 ', 'Na'), ('與', 'Caa'), (' 太', 'Na'), (' 陽 ', 'Na'), ('能 ', 'Na'), ('電', 'Na'), (' 池', 'Na'), (' 產', 'Na'), (' 業', 'Na'), (' ', 'Na'), ('的', 'DE'), (' 蓬', 'Na'), (' 勃 ', 'Na'), ('發', 'VC'), (' 展', 'Na'), (' ', 'Na'), ('，', 'COMMACATEGORY'), (' ', 'FW'), ('對', 'P'), (' ', 'Na'), ('矽', 'Na'), (' 晶', 'Na'), (' 圓', 'Na'), (' 材', 'Na'), (' ', 'Na'), ('料', 'VC'), (' ', 'Na'), ('的', 'DE'), (' ', 'Na'), ('需', 'D'), (' ', 'FW'), ('求', 'VC'), (' 急', 'Na'), (' 速', 'Na'), (' ', 'FW'), ('增', 'VC'), (' 加', 'VC'), (' ', 'Na'), ('，', 'COMMACATEGORY'), (' ', 'Na'), ('矽', 'Na'), (' 晶', 'Na'), (' 圓', 'Na'), (' ', 'Na'), ('製', 'VC'), (' ', 'Na'), ('造 ', 'Na'), ('業', 'Na'), (' ', 'Na'), ('的', 'DE'), (' ', 'FW'), ('產 ', 'Na'), ('能', 'D'), (' 不', 'Na'), (' 斷', 'VH'), (' 增', 'VC'), (' 加', 'VC'), (' ', 'Na'), ('，', 'SHI'), (' ', 'Na'), ('衍', 'VC'), (' 生', 'Na'), (' ', 'Na'), ('的', 'DE'), (' ', 'Na'), ('是', 'SHI'), (' 如', 'Na'), (' 何 ', 'Na'), ('妥 ', 'Na'), ('善 ', 'Na'), ('解 ', 'Na'), ('決 ', 'Na'), ('廢', 'VH'), (' 棄', 'Na'), (' 物', 'Na'), (' ', 'Na'), ('問 ', 'Na'), ('題 ', 'Na'), ('，', 'SHI'), (' ', 'Na'), ('而', 'Cbb'), (' 因', 'Na'), (' ', 'Na'), ('應 ', 'Na'), ('全', 'VH'), (' 球 ', 'Na'), ('永 ', 'Na'), ('續 ', 'Na'), ('發 ', 'Na'), ('展 ', 'Na'), ('的', 'DE'), (' ', 'Na'), ('趨 勢', 'Na'), (' ', 'Na'), ...

# %% [markdown]
# # Result Export

# %%
segmentedElementList = []
labelList = []

for listIndex, elementList in enumerate(tqdm(psegResultList)):
    if len(elementList) > 0:
        for elementIndex, elementTuple in enumerate(elementList):
                segmentedElementList.append(elementTuple[0])
                labelList.append(elementTuple[1])


data_exportPseg = pd.DataFrame({
    "Segmented Element":segmentedElementList,
    "POS":labelList
})


print(data_exportPseg.head())
data_exportPseg.to_csv("../../results/矽晶圓製造業資源化應用技術手冊_monpaResult.csv", encoding="utf8", index=None)
# Out:
# 100%|██████████| 572/572 [00:00<00:00, 47674.86it/s]
#   Segmented Element POS
# 0               矽晶圓  Na
# 1               製造業  Na
# 2                資源  Na
# 3                 化  VG
# 4                應用  Na
