# %% [markdown]
# # Monpa Tryout
# * GitHub Documentation: https://github.com/monpa-team/monpa

# %%
# import packages
from monpa import utils
from tqdm import tqdm
import codecs
import monpa
import numpy as np
import os
import pandas as pd
# Out:
# +---------------------------------------------------------------------+
#   Welcome to MONPA: Multi-Objective NER POS Annotator for Chinese
# +---------------------------------------------------------------------+
# 已找到 model檔。Found model file.

# %%
os.getcwd()
# Out:
# 'D:\\Windows_Storage\\Storage\\Github\\KnowledgeGraph\\scripts\\tokenizations'

# %% [markdown]
# # Import Data

# %%
textElement = ""

for fileIndex, fileElement in enumerate(tqdm(os.listdir("../../data/"))):
    file = codecs.open("../../data/" + fileElement, 'r', encoding='utf8', errors='ignore')
    for textIndex, textLines in enumerate(file):
        textElement += textLines
        
    
print("Text Length: ", len(textElement), " \n\n", textElement[-100:])
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 333.36it/s]
# Text Length:  207715
#
#  管中流過，凝結下來之蒸
#
# 氣附著管外殼上。蒸氣可在管外凝結成一層薄膜後，再排
#
# 至儲存槽，或排出後做適當之處置。在接觸式冷凝器中，
#
# 則噴灑冷的液體以冷凝廢氣中之揮發性成份。
#
# 5 -30

# %% [markdown]
# # Further Train Data

# %%
monpa.load_userdict("../dicts/monpa_userDefinedDict.txt")

# %% [markdown]
# # Shorten Sentence to Fit Monpa Cut/Pseg Function

# %%
textList = utils.short_sentence(textElement)
# for item in textList:
#     print(item)

# %% [markdown]
# # Cut Function

# %%
# cutResultList = []

# for textIndex, textElement in enumerate(textList):
#     cutResult = monpa.cut(textElement)
#     cutResultList.append(cutResult)

# print(cutResultList)

# %% [markdown]
# # Pseg Function

# %%
psegResultList = []

for textIndex, textElement in enumerate(textList):
    psegResult = monpa.pseg(textElement)
    psegResultList.append(psegResult)
#     print(psegResult)

print(psegResultList[:50])
# Out:
# [[('安森美半導體', ''), ('（', 'PARENTHESISCATEGORY'), ('ON Semiconductor', 'FW'), ('）', 'PARENTHESISCATEGORY'), ('，', 'COMMACATEGORY'), ('今天', 'Nd'), ('發表', 'VC'), ('新', 'VH'), ('的', 'DE'), ('RDM', 'FW'), ('系列', 'Na'), ('矽光電倍增管', ''), ('（', 'PARENTHESISCATEGORY'), ('SiPM', 'FW'), ('）', 'PARENTHESISCATEGORY'), (' ', 'FW'), ('陣列', 'Na'), ('，', 'COMMACATEGORY'), ('將', 'P'), ('光學', 'Na'), ('雷達', 'Na'), (' ', 'FW'), ('（', 'PARENTHESISCATEGORY'), ('LiDAR', 'FW'), ('）', 'PARENTHESISCATEGORY'), (' ', 'FW'), ('感測器', 'Na'), ('能力', 'Na'), ('擴展到', 'VC'), ('其', 'Nep'), ('廣泛', 'VH'), ('的', 'T'), ('智慧感測方案', ''), ('陣容', 'Na'), ('。', 'PERIODCATEGORY'), ('ArrayRDM-0112A20-QFN', ''), ('是', 'SHI'), ('市場', 'Nc'), ('上', 'Ncd'), ('首', 'Nes'), ('款', 'Nf'), ('符合', 'VJ'), ('車規', 'Na'), ('的', 'DE'), ('SiPM', 'FW'), ('產品', 'Na'), ('，', 'COMMACATEGORY'), ('以', 'P'), ('滿足', 'VHC'), ('汽車', 'Na'), ('產業', 'Na'), ('及', 'Caa'), ('其他', 'Neqa'), ('領域', 'Na'), ('LiDAR', 'FW'), ('應用', 'Na'), ('中', 'Ng'), ('不斷', 'D'), ('增長', 'VHC'), ('的', 'DE'), ('需求', 'Na'), ('。', 'PERIODCATEGORY')], [('ArrayRDM-0112A20-QFN', ''), ('是', 'SHI'), ('單片', 'Na'), ('1', 'Neu'), ('×', 'FW'), ('12', 'Neu'), (' ', 'FW'), ('SiPM', 'FW'), ('像素', 'Na'), ('陣列', 'Na'), ('，', 'COMMACATEGORY'), ('基於', 'P'), ('安森美半導體', ''), ('領先', 'VJ'), ('市場', 'Nc'), ('的', 'T'), ('RDM製程', ''), ('，', 'COMMACATEGORY'), ('可', 'D'), ('實現', 'VC'), ('對', 'P'), ('近', 'VH'), ('紅', 'VH'), ('外 ', 'Na'), ('（', 'PARENTHESISCATEGORY'), ('NIR', 'FW'), ('）', 'PARENTHESISCATEGORY'), (' ', 'FW'), ('光', 'Na'), ('的', 'DE'), ('高', 'VH'), ('靈敏度', 'Na'), ('，', 'COMMACATEGORY'), ('從而', 'Cbb'), ('在', 'P'), ('905', 'Neu'), ('奈米', 'Nf'), ('（', 'PARENTHESISCATEGORY'), ('nm', 'FW'), ('）', 'PARENTHESISCATEGORY'), ('處', 'D'), ('達到', 'VJ'), ('領先', 'VH'), ('業界', 'Nc'), ('的', 'DE'), ('18.5', 'Neu'), ('％', 'Nf'), ('的', 'DE'), ('光子', 'Na'), ('偵測', 'Nv'), ('效率', 'Na'), (' ', 'FW'), ('（', 'PARENTHESISCATEGORY'), ('PDE', 'FW'), ('）', 'PARENTHESISCATEGORY'), ('。', 'PERIODCATEGORY'), ('SiPM', 'FW'), ('的', 'DE'), ('高', 'VH'), ('內部', 'Ncd'), ('增益', 'Nv'), ('使', 'VL'), ('其', 'Nep'), ('靈敏度', 'Na'), ('可', 'D'), ('達到', 'VJ'), ('單', 'A'), ('光子', 'Na'), ('水準', 'Na'), ('，', 'COMMACATEGORY'), ('該', 'D'), ('功能', 'Na'), ('與', 'Caa'), ('高', 'VH'), ('PDE', 'FW'), ('結合', 'Nv'), ('使用', 'Nv'), ('，', 'COMMACATEGORY'), ('可以', 'D'), ('檢測', 'VC'), ('最', 'Dfa'), ('微弱', 'VH'), ('的', 'DE'), ('返回', 'VCL'), ('信號', 'Na'), ('。', 'PERIODCATEGORY'), ('因此', 'Cbb'), ('，', 'PERIODCATEGORY'), ('即使', 'Cbb'), ('是', 'SHI'), ('低', 'VH'), ('反射', 'Nv'), ('目標', 'Na'), ('，', 'COMMACATEGORY'), ('也', 'D'), ('能', 'D'), ('偵測到', 'VC'), ('更', 'D'), ('遠', 'VH'), ('的', 'DE'), ('距離', 'Na'), ('。', 'PERIODCATEGORY')], [('此外', 'Cbb'), ('，', 'COMMACATEGORY'), ('該', 'Nes'), ('產品', 'Na'), ('符合', 'VJ'), ('AEC-Q102', ''), ('（', 'PARENTHESISCATEGORY'), ('國際汽車電子協會', ''), ('）', 'PARENTHESISCATEGORY'), ('和', 'Caa'), ('按照', 'P'), (' ', 'FW'), ('IATF', 'FW'), (' ', 'FW'), ('16949', 'Neu'), ('（', 'PARENTHESISCATEGORY'), ('國際汽車推動小組', ''), ('）', 'PARENTHESISCATEGORY'), ('的', 'DE'), ('技術', 'Na'), ('規範', 'Na'), ('開發', 'Nv'), ('。', 'PERIODCATEGORY'), ('    ', 'PER'), ('SiPM', 'FW'), ('技術', 'Na'), ('近年', 'Nd'), ('來', 'D'), ('蓬勃', 'VH'), ('發展', 'VC'), ('，', 'COMMACATEGORY'), ('由於', 'Cbb'), ('其', 'Nep'), ('獨特', 'VH'), ('的', 'DE'), ('功能組', 'Na'), ('，', 'COMMACATEGORY'), ('已', 'D'), ('成為', 'VG'), ('廣大', 'VH'), ('市場', 'Nc'), ('深度', 'Na'), ('感測', 'Nv'), ('應用', 'Na'), ('的', 'DE'), ('首選', 'Na'), ('感測器', 'Na'), ('。', 'PERIODCATEGORY'), ('SiPM', 'FW'), ('能', 'D'), ('在', 'P'), ('明亮', 'VH'), ('的', 'DE'), ('陽光', 'Na'), ('條件', 'Na'), ('下', 'Ng'), ('進行', 'VC'), ('長', 'VH'), ('距離', 'Na'), ('測', 'VC'), ('距', 'P'), ('時', 'Ng'), ('提供', 'VD'), ('最', 'Dfa'), ('佳', 'VH'), ('的', 'DE'), ('訊噪', 'Na'), ('比', 'P'), ('性能', 'Na'), ('。', 'PERIODCATEGORY'), ('其他', 'Neqa'), ('優勢', 'Na'), ('包括', 'VK'), ('較', 'Dfa'), ('低', 'VH'), ('的', 'DE'), ('電源', 'Na'), ('偏置', 'Nv'), ('和', 'Caa'), ('較', 'Dfa'), ('低', 'VH'), ('的', 'DE'), ('溫度', 'Na'), ('變化', 'Na'), ('敏感性', 'Na' ...

# %% [markdown]
# # Result Export

# %%
segmentedElementList = []
labelList = []

for listIndex, elementList in enumerate(tqdm(psegResultList)):
    if len(elementList) > 0:
        for elementIndex, elementTuple in enumerate(elementList):
                segmentedElementList.append(elementTuple[0])
                labelList.append(elementTuple[1])


data_exportPseg = pd.DataFrame({
    "Segmented Element":segmentedElementList,
    "POS":labelList
})


print(data_exportPseg.head())
data_exportPseg.to_csv("../../results/210330_result/210330_dataset_monpaResult.csv", encoding="utf8", index=None)
# Out:
# 100%|██████████| 1332/1332 [00:00<00:00, 26641.30it/s]
#   Segmented Element                  POS
# 0            安森美半導體
# 1                 （  PARENTHESISCATEGORY
# 2  ON Semiconductor                   FW
# 3                 ）  PARENTHESISCATEGORY
# 4                 ，        COMMACATEGORY
