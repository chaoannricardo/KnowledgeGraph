# %% [markdown]
# # spaCy Tryout
# * Documnetation: https://spacy.io/models/zh

# %%
# import packages needed
from monpa import utils
from spacy.lang.zh.examples import sentences 
from tqdm import tqdm
import codecs
import spacy
import numpy as np
import pandas as pd
# Out:
# +---------------------------------------------------------------------+
#   Welcome to MONPA: Multi-Objective NER POS Annotator for Chinese
# +---------------------------------------------------------------------+
# 已找到 model檔。Found model file.

# %% [markdown]
# # Import Data

# %%
textElement = ""

file = codecs.open("../../data/矽晶圓製造業資源化應用技術手冊.txt", 'r', encoding='utf8', errors='ignore')

for textIndex, textLines in enumerate(file):
#     textList.append(textLines)
    textElement += textLines

# %% [markdown]
# # Cuting to small pieces by MONPA

# %%
textList = utils.short_sentence(textElement)

# %% [markdown]
# # Pseg Function

# %%
nlp = spacy.load("zh_core_web_trf")

psegResultList = []
allWords = []
allFlags = []
allDep = []

for textIndex, text in enumerate(textList):
    doc = nlp(text)
    for token in doc:
        allWords.append(token.text)
        allFlags.append(token.pos_)
        allDep.append(token.dep_)
    #    print(token.text, token.pos_, token.dep_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-31d51ae88cba> in <module>
#       7
#       8 for textIndex, text in enumerate(textList):
# ----> 9     doc = nlp(text)
#      10     for token in doc:
#      11         allWords.append(token.text)
#
# D:\Anaconda3\envs\monpa\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     988                 error_handler = proc.get_error_handler()
#     989             try:
# --> 990                 doc = proc(doc, **component_cfg.get(name, {}))
#     991             except KeyError as e:
#     992                 # This typically happens if a component is not initialized
#
# D:\Anaconda3\envs\monpa\lib\site-packages\spacy_transformers\pipeline_component.py in __call__(self, doc)
#     181         DOCS: https://nightly.spacy.io/api/transformer#call
#     182         """
# ...

# %%
data_exportPseg = pd.DataFrame({
    "Segmented Element":allWords,
    "POS":allFlags,
    "Dependecies":allDep
})


print(data_exportPseg.head())
data_exportPseg.to_csv("../../results/矽晶圓製造業資源化應用技術手冊_spaCy.csv", encoding="utf8", index=None)
