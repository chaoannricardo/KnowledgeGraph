# %%
import spacy

# %%
nlp1 = spacy.load(R".\model")

# %%
doc = nlp1("1976年，喬布斯與另一位聯合創始人史蒂夫·沃茲尼亞克一起創立了蘋果公司，發明了第一台蘋果電腦，並負責將包括iPod和iPhone在內的蘋果產品成功推向市場")

token_list = []
dep_list = []
pos_list = []

for token in doc:
    token_list.append(token)
    dep_list.append(token.dep_)
    pos_list.append(token.pos_)
    
print(token_list)
print(dep_list)
print(pos_list)
# Out:
# [4月, 9日, 下午, ，, 鍾祥市, 檢察院, 與市, 志願者, 協會, 在, 鍾祥市, 實驗, 小學, 聯合, 舉辦, 了, 平安, 創建, ，, 護苗, 2019·未成年人, 保護, 安全, 教育, 啓動, 儀式, 暨, 女童, 保護, 防性, 侵, 生命, 安全, 教育, 進校, 園活, 動, 市政, 法委, 綜治辦, 、, 市, 檢察院, 、, 市, 教育局, 、, 市, 婦聯, 、, 團, 市委, 等, 單位, 的, 領導, 參加, 了, 啓動, 儀式, 市, 檢察院, 副檢察長, 董厚斌, 、, 市, 教育局, 副局長許, 先勇, 、, 實驗, 小, 學校, 長易, 前進, 分別, 在, 啓動, 儀式, 上, 作, 了, 重要, 講話]
# ['compound:nn', 'compound:nn', 'nmod:tmod', 'punct', 'nmod:assmod', 'conj', 'compound:nn', 'compound:nn', 'nsubj', 'case', 'compound:nn', 'amod', 'nmod:prep', 'advmod', 'ROOT', 'aux:asp', 'advmod', 'acl', 'punct', 'dep', 'dep', 'conj', 'dobj', 'compound:nn', 'compound:nn', 'conj', 'cc', 'nsubj', 'acl', 'compound:vc', 'advmod:rcomp', 'compound:nn', 'dobj', 'nsubj', 'compound:nn', 'dobj', 'dobj', 'compound:nn', 'compound:nn', 'conj', 'punct', 'compound:nn', 'conj', 'punct', 'compound:nn', 'conj', 'punct', 'compound:nn', 'conj', 'punct', 'compound:nn', 'compound:nn', 'etc', 'nmod:assmod', 'case', 'nsubj', 'ROOT', 'aux:asp', 'compound:nn', 'dobj', 'compound:nn', 'compound:nn', 'appos', 'conj', 'punct', 'compound:nn', 'compound:nn', 'appos', 'conj', 'punct', 'compound:nn', 'compound:nn', 'compound:nn', 'appos', 'nsubj', 'advmod', 'case', 'compound:nn', 'nmod:prep', 'case', 'ROOT', 'aux:asp', 'amod', 'dobj']
# ['NOUN', 'NOUN', 'NOUN', 'PUNCT', 'PROPN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'PROPN', 'ADJ', 'NOUN', 'ADV', 'VERB', 'PART', 'NOUN', 'VERB', 'PUNCT', 'VERB', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'CCONJ', 'NOUN', 'VERB', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT', 'NOUN', 'NOUN', 'PUNCT', 'PROPN', 'NOUN', 'PART', 'NOUN', 'PART', 'NOUN', 'VERB', 'PART', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'PROPN', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PROPN', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'PROPN', 'ADV', 'ADP', 'NOUN', 'NOUN', 'PART', 'VERB', 'PART', 'ADJ', 'NOUN']
