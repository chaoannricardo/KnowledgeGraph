# %%
import spacy

# %%
nlp1 = spacy.load(R"../../../KnowledgeGraph_materials/models_kg/210506_spacy_model")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-978679f5cc9e> in <module>
# ----> 1 nlp1 = spacy.load(R"../../../KnowledgeGraph_materials/models_kg/210506_spacy_model")
#
# D:\Anaconda3\lib\site-packages\spacy\__init__.py in load(name, disable, exclude, config)
#      45     RETURNS (Language): The loaded nlp object.
#      46     """
# ---> 47     return util.load_model(name, disable=disable, exclude=exclude, config=config)
#      48
#      49
#
# D:\Anaconda3\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     322             return load_model_from_package(name, **kwargs)
#     323         if Path(name).exists():  # path to model data directory
# --> 324             return load_model_from_path(Path(name), **kwargs)
#     325     elif hasattr(name, "exists"):  # Path or Path-like to model data
# ...

# %%
doc = nlp1("1976年，喬布斯與另一位聯合創始人史蒂夫·沃茲尼亞克一起創立了蘋果公司，發明了第一台蘋果電腦，並負責將包括iPod和iPhone在內的蘋果產品成功推向市場")

token_list = []
dep_list = []
pos_list = []

for token in doc:
    token_list.append(token)
    dep_list.append(token.dep_)
    pos_list.append(token.pos_)
    
print(token_list)
print(dep_list)
print(pos_list)
# Out:
# [1976年, ，, 喬布斯與, 另, 一, 位, 聯合, 創始人, 史蒂夫·沃茲尼亞克, 一起, 創立, 了, 蘋果, 公司, ，, 發明, 了, 第一, 台, 蘋果, 電腦, ，, 並負, 責將, 包括, iPod, 和, iPhone, 在, 內, 的, 蘋果, 產品, 成功, 推向市, 場]
# ['nmod:tmod', 'punct', 'case', 'det', 'dep', 'mark:clf', 'amod', 'appos', 'nsubj', 'advmod', 'ROOT', 'aux:asp', 'compound:nn', 'dobj', 'punct', 'conj', 'aux:asp', 'nummod', 'mark:clf', 'compound:nn', 'dobj', 'punct', 'conj', 'conj', 'acl', 'conj', 'cc', 'advmod:loc', 'case', 'case', 'mark', 'compound:nn', 'dep', 'advmod', 'ccomp', 'dobj']
# ['NOUN', 'PUNCT', 'PROPN', 'DET', 'NUM', 'NUM', 'ADJ', 'NOUN', 'PROPN', 'ADV', 'VERB', 'PART', 'PROPN', 'NOUN', 'PUNCT', 'VERB', 'PART', 'NUM', 'NUM', 'PROPN', 'NOUN', 'PUNCT', 'VERB', 'VERB', 'VERB', 'PUNCT', 'CCONJ', 'PUNCT', 'PART', 'PART', 'PART', 'PROPN', 'NOUN', 'ADV', 'VERB', 'NOUN']
