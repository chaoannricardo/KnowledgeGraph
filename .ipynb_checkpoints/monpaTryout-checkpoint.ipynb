# %% [markdown]
# # Monpa Tryout
# * GitHub Documentation: https://github.com/monpa-team/monpa

# %%
# import packages
from monpa import utils
from tqdm import tqdm
import codecs
import monpa
import numpy as np
import pandas as pd
# Out:
# +---------------------------------------------------------------------+
#   Welcome to MONPA: Multi-Objective NER POS Annotator for Chinese
# +---------------------------------------------------------------------+
# 已找到 model檔。Found model file.

# %% [markdown]
# # Import Data

# %%
textElement = ""

file = codecs.open("./data/第二十三章半導體製造概論.txt", 'r', encoding='utf8', errors='ignore')

for textIndex, textLines in enumerate(file):
    textElement += textLines
    
print(textElement[:500])
# Out:
# 第二十三章 半導體製造概論
#
# 第二十三章 半導體製造概論
#
# 近幾年來，隨著電子科技、網路等相關技術的進步，以及全球電子市場消費水準的提昇，個人電腦、多媒體、工作站、網路、通信相關設備等電子產品的需求量激增，帶動整個世界半導體產業的蓬勃發展，而在台灣，半導體業更儼然成為維繫國家經濟動脈的一個主力。基本上半導體製造為一垂直分工細密且高附加價值的產業，其快速的成長也會帶動其他週邊產業的繁榮，下圖所示為一典型的半導體產業體系架構。
#
#
# 在這個體系中，半導體製造，也就是一般所稱的晶圓加工（Wafer fabrication），是資金與技術最為密集之處，伴隨著晶圓加工的上游產業則包括產品設計（IC design）、晶圓製造（Wafer manufacture）、以及光罩（Photo mask）製造等，下游產業則更為龐大，其中包括一般所稱半導體後段製程（Back-end processes）的 IC 封裝（Packaging）、測試（Testing）、包裝（Assembly），以及週邊的導線架製造（Lead-frame manufacture）、連接器製造（Connect

# %% [markdown]
# # Further Train Data

# %%
monpa.load_userdict("./userDefinedDict.txt")

# %% [markdown]
# # Shorten Sentence to Fit Monpa Cut/Pseg Function

# %%
textList = utils.short_sentence(textElement)
for item in textList:
    print(item)
# Out:
# 半導體工業常用的化學試劑可分為酸、鹼、有機溶劑和有機物質及氧化物等五大類，分別用於不同的生產過程中。隨著 IC 技術的不斷發展，尤其當今已邁進線寬小於 0.10μm 的奈米電子時代，對矽晶圓單晶拋光片的表面加工質量的要求也越來越高，同樣對所用的超高純化學試劑提出了更高的技術要求，要求其顆粒、雜質的含量比一般要減少 1～3 個數量級，並對其包裝、儲、運等也提出了相應的新要求。
# 矽晶圓片的化學清洗製程所用的超高純度化學試劑的 SEMI 標準的主要技術指標見表 4.2-2 所示。根據 SEMI 標準，SEMI-C7 標準的試劑適用於 1.2～0.8μm 線寬電路生產，SEMI-C8 標準的試劑適用於 0.6～0.2μm 線寬電路製程，SEMI-C12 標準的試劑適用於 0.2～0.09μm 線寬電路製程。
# 用於半導體工廠的化學試劑用量比較大，為了安全避免系統的污染，均採用中央系統管理、供應方式的化學試劑的供給系統。酸、鹼化學試劑的輸送均採用含氟的高分子材料（氟塑料「TEFLON」）PFA 材質的雙層管路系統，內層PFA 材質管路輸送酸、鹼化學試劑，外層一般採用透明的 U-PVC 材質管，以供泄漏監視之用同時在內外管之間通入經稀釋的氮氣，並接至廢氣的排放管路系統中。
# 所用的有機溶劑常用不銹鋼管 SUS316L（內壁經拋光處理）作為輸送管路。由於酸、鹼化學試劑和有機溶劑會對人體造成很大的傷害，故應有嚴格的安全、防護措施及裝備、管路輸送系統中應配置泄漏監視系統。

# %% [markdown]
# # Cut Function

# %%
cutResultList = []

for textIndex, textElement in enumerate(textList):
    cutResult = monpa.cut(textElement)
    cutResultList.append(cutResult)

print(cutResultList)
# Out:
# [['半導體', '工業', '常', '用', '的', '化學', '試劑', '可', '分為', '酸', '、', '鹼', '、', '有機', '溶劑', '和', '有機', '物質', '及', '氧化物', '等', '五', '大', '類', '，', '分別', '用於', '不同', '的', '生產', '過程', '中', '。', '隨著', ' ', 'IC', ' ', '技術', '的', '不斷', '發展', '，', '尤其', '當今', '已', '邁進', '線', '寬', '小於', ' ', '0.10', 'μm', ' ', '的', '奈米', '電子', '時代', '，', '對', '矽', '晶圓', '單晶', '拋光片', '的', '表面', '加工', '質量', '的', '要求', '也', '越', '來', '越', '高', '，', '同樣', '對', '所', '用', '的', '超高', '純化', '學試劑', '提出', '了更高', '的', '技術', '要求', '，', '要求', '其', '顆', '粒', '、', '雜質', '的', '含量', '比', '一般', '要', '減少', ' ', '1～', '3', ' ', '個', '數', '量級', '，', '並', '對', '其', '包裝', '、', '儲', '、', '運', '等', '也', '提出', '了', '相應', '的', '新', '要求', '。'], ['矽晶', '圓片', '的', '化學', '清洗', '製程', '所', '用', '的', '超高', '純度', '化學', '試劑', '的', ' ', 'SEMI', ' ', '標準', '的', '主要', '技術', '指標', '見表', ' ', '4.2', '-', '2', ' ', '所', '示', '。', '根據', ' ', 'SEMI', ' ', '標準', '，', 'SEMI-C', '7', ' ', '標準', '的', '試劑', '適用', '於', ' ', '1.2', '～', '0.8', 'μm', ' ', '線', '寬', '電路', '生產', '，', 'SEMI', '-', 'C', '8', ' ', '標準', '的', '試劑', '適用', '於', ' ', '0.6', '～', '0.2', 'μm', ' ', '線', '寬', '電路', '製程', '，', 'S', 'EMI', '-', 'C', '12', ' ', '標準', '的', '試劑', '適用', '於', ' ', '0.2', '～', '0.09', 'μm', ' ', '線', '寬', '電路', '製程', '。'], ['用於', '半導體', '工廠', '的', '化學', '試劑', '用量', '比較', '大', '，', '為', '了', '安全', '避免', '系統', '的', '污染', '，', '均', '採用', '中央', '系統', '管理', '、', '供應', '方式', '的', '化學', '試劑', '的', '供給', '系統', '。', '酸', '、', '鹼化學', '試劑', '的', '輸送', '均', '採用', '含氟', '的', '高分子', '材料', '（', '氟', '塑料', '「', 'TEFLON', '」', '）', 'PFA', ' ', '材質', '的', '雙層', '管路', '系統', '，', '內', '層', 'PFA', ' ', '材質', '管路', '輸送', '酸', '、', '鹼化學', '試劑', '，', '外層', '一般', '採用', '透明', '的', ' ', 'U-PVC', ' ', '材質管', '，', '以', '供', '泄漏', '監視', '之', '用', '同時', '在', '內', '外管', '之間', '通入經', '稀釋', '的', '氮氣', '，', '並', '接至', '廢氣', '的', '排放', '管路', '系統', '中', '。'], ['所', '用', '的', '有機', '溶劑', '常', '用', '不銹', '鋼管', ' SUS316L', '（', '內壁', '經', '拋光', '處理', '）', '作為', '輸送', '管路', '。', '由於', '酸', '、', '鹼化學', '試劑', '和', '有機', '溶劑', '會', '對', '人體', '造成', '很', '大', '的', '傷害', '，', '故', '應有', '嚴格', '的', '安全', '、', '防護', '措施', '及', '裝備', '、', '管路', '輸送', '系統', '中', '應', '配置', '泄', '漏', '監視', '系統', '。']]

# %% [markdown]
# # Pseg Function

# %%
psegResultList = []

for textIndex, textElement in enumerate(textList):
    psegResult = monpa.pseg(textElement)
    psegResultList.append(psegResult)
#     print(psegResult)

print(psegResultList)
# Out:
# [[('半導體', 'Na'), ('工業', 'Na'), ('常', 'D'), ('用', 'VC'), ('的', 'DE'), ('化學', 'Na'), ('試劑', 'Na'), ('可', 'D'), ('分為', 'VG'), ('酸', 'Na'), ('、', 'PAUSECATEGORY'), ('鹼', 'Na'), ('、', 'PAUSECATEGORY'), ('有機', 'A'), ('溶劑', 'Na'), ('和', 'Caa'), ('有機', 'A'), ('物質', 'Na'), ('及', 'Caa'), ('氧化物', 'Na'), ('等', 'Cab'), ('五', 'Neu'), ('大', 'VH'), ('類', 'Na'), ('，', 'COMMACATEGORY'), ('分別', 'D'), ('用於', 'VC'), ('不同', 'VH'), ('的', 'DE'), ('生產', 'Nv'), ('過程', 'Na'), ('中', 'Ng'), ('。', 'PERIODCATEGORY'), ('隨著', 'P'), (' ', 'FW'), ('IC', 'FW'), (' ', 'FW'), ('技術', 'Na'), ('的', 'DE'), ('不斷', 'VH'), ('發展', 'Nv'), ('，', 'COMMACATEGORY'), ('尤其', 'D'), ('當今', 'Nd'), ('已', 'D'), ('邁進', 'VCL'), ('線', 'Na'), ('寬', 'VH'), ('小於', 'VJ'), (' ', 'FW'), ('0.10', 'Neu'), ('μm', 'Nf'), (' ', 'Na'), ('的', 'DE'), ('奈米', 'Na'), ('電子', 'Na'), ('時代', 'Na'), ('，', 'COMMACATEGORY'), ('對', 'P'), ('矽', 'Na'), ('晶圓', 'Na'), ('單晶', 'Na'), ('拋光片', 'Na'), ('的', 'DE'), ('表面', 'Na'), ('加工', 'VA'), ('質量', 'Na'), ('的', 'DE'), ('要求', 'Na'), ('也', 'D'), ('越', 'D'), ('來', 'VC'), ('越', 'D'), ('高', 'VH'), ('，', 'PERIODCATEGORY'), ('同樣', 'D'), ('對', 'P'), ('所', 'D'), ('用', 'VC'), ('的', 'DE'), ('超高', 'VH'), ('純化', 'VH'), ('學試劑', 'Na'), ('提出', 'VC'), ('了更高', 'VH'), ('的', 'DE'), ('技術', 'Na'), ('要求', 'Na'), ('，', 'SHI'), ('要求', 'VF'), ('其', 'Nep'), ('顆', 'Nf'), ('粒', 'Na'), ('、', 'PAUSECATEGORY'), ('雜質', 'Na'), ('的', 'DE'), ('含量', 'Na'), ('比', 'P'), ('一般', 'A'), ('要', 'D'), ('減少', 'VHC'), (' ', 'FW'), ('1～', 'Neu'), ('3', 'Neu'), (' ', 'FW'), ('個', 'Nf'), ('數', 'Na'), ('量級', 'Na'), ('，', 'COMMACATEGORY'), ('並', 'Cbb'), ('對', 'P'), ('其', 'Nep'), ('包裝', 'Na'), ('、', 'PAUSECATEGORY'), ('儲', 'VC'), ('、', 'PAUSECATEGORY'), ('運', 'VC'), ('等', 'Cab'), ('也', 'D'), ('提出', 'VC'), ('了', 'D'), ('相應', 'VH'), ('的', 'DE'), ('新', 'VH'), ('要求', 'Na'), ('。', 'PERIODCATEGORY')], [('矽晶', 'Na'), ('圓片', 'Na'), ('的', 'DE'), ('化學', 'Na'), ('清洗', 'Nv'), ('製程', 'Na'), ('所', 'D'), ('用', 'VC'), ('的', 'DE'), ('超高', 'VH'), ('純度', 'Na'), ('化學', 'Na'), ('試劑', 'Na'), ('的', 'DE'), (' ', 'FW'), ('SEMI', 'FW'), (' ', 'FW'), ('標準', 'Na'), ('的', 'DE'), ('主要', 'A'), ('技術', 'Na'), ('指標', 'Na'), ('見表', 'Na'), (' ', 'FW'), ('4.2', 'Neu'), ('-', 'DASHCATEGORY'), ('2', 'Neu'), (' ', 'FW'), ('所', 'D'), ('示', 'VE'), ('。', 'PERIODCATEGORY'), ('根據', 'P'), (' ', 'FW'), ('SEMI', 'FW'), (' ', 'FW'), ('標準', 'Na'), ('，', 'COMMACATEGORY'), ('SEMI-C', 'FW'), ('7', 'Neu'), (' ', 'FW'), ('標準', 'Na'), ('的', 'DE'), ('試劑', 'Na'), ('適用', 'VC'), ('於', 'P'), (' ', 'FW'), ('1.2', 'Neu'), ('～', 'PERIODCATEGORY'), ('0.8', 'Neu'), ('μm', 'FW'), (' ', 'FW'), ('線', 'Na'), ('寬', 'VH'), ('電路', 'Na'), ('生產', 'Nv'), ('，', 'COMMACATEGORY'), ('SEMI', 'FW'), ('-', 'DASHCATEGORY'), ('C', 'FW'), ('8', 'Neu'), (' ', 'Na'), ('標準', 'Na'), ('的', 'DE'), ('試劑', 'Na'), ('適用', 'VC'), ('於', 'P'), (' ', 'FW'), ('0.6', 'Neu'), ('～', 'PERIODCATEGORY'), ('0.2', 'Neu'), ('μm', 'Nf'), (' ', 'FW'), ('線', 'Na'), ('寬', 'VH'), ('電路', 'Na'), ('製程', 'Na'), ('，', 'SHI'), ('S', 'FW'), ('EMI', 'FW'), ('-', 'DASHCATEGORY'), ('C', 'FW'), ('12', 'Neu'), (' ', 'Na'), ('標準', 'Na'), ('的', 'DE'), ('試劑', 'Na'), ('適用', 'VC'), ('於', 'P'), (' ', 'FW'), ('0.2', 'Neu'), ('～', 'PERIODCATEGORY'), ('0.09', 'Neu'), ('μm', 'FW'), (' ', 'FW'), ('線', 'Na'), ('寬', 'VH'), ('電路', 'Na'), ('製程', 'Na'), ('。', 'PERIODCATEGORY')], [('用於', 'VC'), ('半導體', 'Na'), ('工廠', 'Nc'), ('的', 'DE'), ('化學', 'Na'), ('試劑', 'Na'), ('用量', 'Na'), ('比較', 'Dfa'), ('大', 'VH'), ('，', 'COMMACATEGORY'), ('為', 'P'), ('了', 'VG'), ('安全', 'VH'), ('避免', 'VE'), ('系統', 'Na'), ('的', 'DE'), ('污染', 'Na'), ('，', 'COMMACATEGORY'), ('均', 'D'), ('採用', 'VC'), ('中央', 'Nc'), ('系統', 'Na'), ('管理', 'Na'), ('、', 'PAUSECATEGORY'), ('供應', 'VD'), ('方式', 'Na'), ('的', 'DE'), ('化學', 'Na'), ('試劑', 'Na'), ('的', 'DE'), ('供給', 'VD'), ('系統', 'Na'), ('。', 'PERIODCATEGORY'), ('酸', 'Na'), ('、', 'PAUSECATEGORY'), ('鹼化學', 'Na'), ('試劑', 'Na'), ('的', 'DE'), ('輸送', 'Nv'), ('均', 'D'), ('採用', 'VC'), ('含氟', 'Na'), ('的', 'DE'), ('高分子', 'Na'), ('材料', 'Na'), ('（', 'PARENTHESISCATEGORY ...

# %% [markdown]
# # Result Export

# %%
segmentedElementList = []
labelList = []

for listIndex, elementList in enumerate(tqdm(psegResultList)):
    if len(elementList) > 0:
        for elementIndex, elementTuple in enumerate(elementList):
                segmentedElementList.append(elementTuple[0])
                labelList.append(elementTuple[1])


data_exportPseg = pd.DataFrame({
    "Segmented Element":segmentedElementList,
    "Label":labelList
})


print(data_exportPseg.head())
data_exportPseg.to_csv("./result/monpaResult_2.csv", encoding="utf8", index=None)
# Out:
# 100%|██████████| 4/4 [00:00<?, ?it/s]
#   Segmented Element Label
# 0               半導體    Na
# 1                工業    Na
# 2                 常     D
# 3                 用    VC
# 4                 的    DE
