# %% [markdown]
# # spaCy Tryout
# * Documnetation: https://spacy.io/models/zh

# %%
# import packages needed
from spacy.lang.zh.examples import sentences 
from tqdm import tqdm
import codecs
import spacy
import numpy as np
import pandas as pd

# %% [markdown]
# # Import Data

# %%
textElement = ""

file = codecs.open("./data/textDoc_2.txt", 'r', encoding='utf8', errors='ignore')

for textIndex, textLines in enumerate(file):
#     textList.append(textLines)
    textElement += textLines

# %% [markdown]
# # Pseg Function

# %%
nlp = spacy.load("zh_core_web_trf")

psegResultList = []
allWords = []
allFlags = []
allDep = []

doc = nlp(textElement)
for token in doc:
#         print(token.text, token.pos_, token.dep_)
    allWords.append(token.text)
    allFlags.append(token.pos_)
    allDep.append(token.dep_)

# %%
data_exportPseg = pd.DataFrame({
    "Segmented Element":allWords,
    "Label":allFlags,
    "Dependecies":allDep
})


print(data_exportPseg.head())
data_exportPseg.to_csv("./result/spacyResult_2.csv", encoding="utf8", index=None)
# Out:
#   Segmented Element Label  Dependecies
# 0                半導  NOUN  compound:nn
# 1                體工  NOUN  compound:nn
# 2                業常  NOUN          dep
# 3                 用  VERB          acl
# 4                 的  PART         mark
